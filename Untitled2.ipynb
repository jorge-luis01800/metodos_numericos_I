# %% [markdown]
# <a href="https://colab.research.google.com/github/jorge-luis01800/metodos_numericos_I/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def f(x):
  return (x-2)**2
print(f"f(2)={f(2)}")
# Out:
# f(2)=0
